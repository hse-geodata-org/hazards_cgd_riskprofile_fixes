# %%
import os
import pandas as pd
import sys
import time

# %%
import arcpy

# %%
# ========= CONFIGURE THESE =========
region    = "KHMAO"
gdb_path  = r"C:\Users\User\Documents\ЦГД\KHMAO_RiskProfile_30-09-2025\KHMAO_RiskProfile\Default.gdb"
RISKS_FDS = "risk"   # feature dataset that holds risk layers
EXCEL_PATH = r"C:\Users\User\Documents\ЦГД\Структура базы_v03.xlsx"   # <-- put your local path here
SHEET_INDEX = 1       # 0=Economics, 1=Risks
DRY_RUN     = False   # True → only print, False → apply AlterField
VERBOSE_SKIPS = False # True → print per-field skips (can be very chatty)
LOG_EVERY   = 25      # print a heartbeat every N fields inside a FC

# ========= UTILS =========
def print_flush(*args, **kwargs):
    """print + flush so you see progress immediately in VS Code/terminal."""
    print(*args, **kwargs)
    sys.stdout.flush()

def secs(dt):
    """Format seconds nicely."""
    return f"{dt:.2f}s"

# ========= READ ALIAS MAP FROM EXCEL =========
t0 = time.time()
print_flush(f"[1/6] Reading Excel: {EXCEL_PATH} (sheet index={SHEET_INDEX}) ...")
df = pd.read_excel(EXCEL_PATH, sheet_name=SHEET_INDEX)
print_flush(f"       Rows read: {len(df)}; Columns: {list(df.columns)}")

# Normalize headers for flexible detection
hdr_map = {c: str(c).strip().lower() for c in df.columns}
df.columns = [hdr_map[c] for c in df.columns]

# Candidate columns for field names and aliases
name_candidates  = ["field_name_tot", "название поля", "name"]
alias_candidates = ["псевдонимы", "псевдоним", "alias", "field_alias"]

def pick_col(cands, cols):
    for c in cands:
        if c in cols:
            return c
    raise ValueError(f"Не найден столбец среди вариантов: {cands} | имеющиеся: {list(cols)}")

name_col  = pick_col(name_candidates,  df.columns)
alias_col = pick_col(alias_candidates, df.columns)
print_flush(f"       Detected columns -> name: '{name_col}', alias: '{alias_col}'")

# Build mapping: exact field name (as in GDB) -> alias
df = df[[name_col, alias_col]].dropna()
df[name_col]  = df[name_col].astype(str).str.strip()
df[alias_col] = df[alias_col].astype(str).str.strip()

alias_map_exact = dict(zip(df[name_col], df[alias_col]))
alias_map_lower = {k.lower(): v for k, v in alias_map_exact.items()}
print_flush(f"       Alias rows usable: {len(alias_map_exact)} "
            f"(example: {list(alias_map_exact.items())[:3]})")
print_flush(f"       Excel read & mapping built in {secs(time.time()-t0)}")

# ========= FIND FEATURE CLASSES IN 'risk' =========
arcpy.env.workspace = os.path.join(gdb_path, RISKS_FDS)
fcs = arcpy.ListFeatureClasses() or []
print_flush(f"\n[2/6] Scanning feature dataset: {RISKS_FDS}")
print_flush(f"       Feature classes found: {len(fcs)}")
if fcs:
    preview = ", ".join(fcs[:5])
    print_flush(f"       First few FCs: {preview}{' ...' if len(fcs) > 5 else ''}")

# ========= APPLY ALIASES =========
print_flush(f"\n[3/6] Starting alias updates (DRY_RUN={DRY_RUN}) ...")

changes = []   # (fc, field_name, old_alias, new_alias, duration_s)
skipped = []   # (fc, field_name, reason)

grand_total_fields = 0
grand_to_change    = 0

for idx, fc in enumerate(fcs, start=1):
    if "template" in fc.lower():
        skipped.append((fc, None, "template fc skipped"))
        continue

    fc_path = os.path.join(gdb_path, RISKS_FDS, fc)
    print_flush(f"\n[FC {idx}/{len(fcs)}] {fc} -> {fc_path}")
    t_fc = time.time()

    try:
        fields = arcpy.ListFields(fc_path)
    except Exception as e:
        print_flush(f"       ERROR: cannot ListFields -> {e}")
        skipped.append((fc, None, f"ListFields error: {e}"))
        continue

    # exclude OID/Geometry
    data_fields = [f for f in fields if f.type not in ("OID", "Geometry")]
    print_flush(f"       Fields (excl. OID/Geometry): {len(data_fields)}")
    grand_total_fields += len(data_fields)

    to_change = 0
    processed = 0

    for i, f in enumerate(data_fields, start=1):
        processed += 1
        # heartbeat
        if (processed % LOG_EVERY) == 0:
            print_flush(f"         ...processed {processed}/{len(data_fields)} fields")

        desired = alias_map_exact.get(f.name) or alias_map_lower.get(f.name.lower())
        if not desired:
            if VERBOSE_SKIPS:
                print_flush(f"         SKIP (no alias in Excel): {f.name} | current='{f.aliasName}'")
            skipped.append((fc, f.name, "alias not found in Excel"))
            continue

        current_alias = f.aliasName or ""
        if current_alias == desired:
            if VERBOSE_SKIPS:
                print_flush(f"         OK (already correct): {f.name} -> '{current_alias}'")
            skipped.append((fc, f.name, "already correct"))
            continue

        to_change += 1
        t_field = time.time()
        msg = f"         CHANGE: {f.name}: '{current_alias}' -> '{desired}'"
        if DRY_RUN:
            print_flush(msg + " [dry-run]")
            changes.append((fc, f.name, current_alias, desired, 0.0))
            continue

        print_flush(msg + " ... applying")
        try:
            arcpy.management.AlterField(
                in_table=fc_path,
                field=f.name,
                new_field_name=None,        # keep actual name
                new_field_alias=desired,    # set alias
                field_type=None,
                field_length=None,
                field_is_nullable=None,
                clear_field_alias=False
            )
            dur = time.time() - t_field
            print_flush(f"           ✔ done in {secs(dur)}")
            changes.append((fc, f.name, current_alias, desired, dur))
        except Exception as e:
            print_flush(f"           ✖ ERROR: {e}")
            skipped.append((fc, f.name, f"ERROR: {e}"))

    dur_fc = time.time() - t_fc
    grand_to_change += to_change
    print_flush(f"       FC summary: processed={processed}, changed={to_change}, "
                f"skipped={processed - to_change} | took {secs(dur_fc)}")

# ========= REPORT =========
print_flush(f"\n[4/6] Summary across all FCs in '{RISKS_FDS}'")
print_flush(f"       Total fields seen: {grand_total_fields}")
print_flush(f"       Total fields changed: {grand_to_change}")
print_flush(f"       Total skipped: {len(skipped)}")

# breakdown of skip reasons (top few)
reason_counts = {}
for _, _, r in skipped:
    reason_counts[r] = reason_counts.get(r, 0) + 1
if reason_counts:
    print_flush("       Skip reasons:")
    for r, n in sorted(reason_counts.items(), key=lambda x: -x[1])[:10]:
        print_flush(f"         {r}: {n}")

# optional: print the first few changes
if changes:
    print_flush("\n[5/6] Example changes (first 10):")
    for rec in changes[:10]:
        fc, fld, old, new, dur = rec
        print_flush(f"       [{fc}] {fld}: '{old}' -> '{new}' in {secs(dur)}")

print_flush(f"\n[6/6] DONE. DRY_RUN={DRY_RUN}.")
# Out:
# [1/6] Reading Excel: C:\Users\User\Documents\ЦГД\Структура базы_v03.xlsx (sheet index=1) ...
#        Rows read: 66; Columns: ['Группа полей', 'БДv01\nПоле шейпа (10 симв., латынь)', 'field_name', 'field_name_tot', 'Тип данных', 'alias', 'Размерность', 'Метео ОПЯ?', 'Неметео ОПЯ?', 'Описание', 'Откуда берутся данные', 'Если есть modelBuilder']
#        Detected columns -> name: 'field_name_tot', alias: 'alias'
#        Alias rows usable: 63 (example: [('region', 'Регион'), ('MO', 'МО'), ('area', 'Площадь общая')])
#        Excel read & mapping built in 1.10s
#
# [2/6] Scanning feature dataset: risk
#        Feature classes found: 11
#        First few FCs: KHMAO_hazHeat_MO, KHMAO_hazardTemplate_MO, KHMAO_hazCold_MO, KHMAO_hazRain_MO, KHMAO_hazThunderstorm_MO ...
#
# [3/6] Starting alias updates (DRY_RUN=False) ...
#
# [FC 1/11] KHMAO_hazHeat_MO -> C:\Users\User\Documents\ЦГД\KHMAO_RiskProfile_30-09-2025\KHMAO_RiskProfile\Default.gdb\risk\KHMAO_hazHeat_MO
#        Fields (excl. OID/Geometry): 67
#          CHANGE: region: 'region' -> 'Регион' ... applying
#            ✔ done in 6.24s
#          CHANGE: MO: 'MO' -> 'МО' ... applying
#            ✔ done in 0.81s
#          CHANGE: area: 'area' -> 'Площадь общая' ... applying
#            ✔ done in 0.84s
#          CHANGE: areaLive: 'areaLive' -> 'Площадь освоенная' ... applying
#            ✔ done in 0.77s
#          CHANGE: areaLiveF: 'areaLiveF' -> 'Площадь освоенная, доля' ... applying
#            ✔ done in 0.80s
#          CHANGE: sTot: 'sTot' -> 'Подверженная область в МО' ... applying
#            ✔ done in 0.80s
#          CHANGE: sTotFrac: 'sTotFrac' -> 'Подверженная область в МО, доля' ... applying
#            ✔ done in 0.95s
#          CHANGE: sLive: 'sLive' -> 'Подверженная область на освоенной территории' ... applying
#            ✔ done in 0.81s
#          CHANGE: sLiveFrac: 'sLiveFrac' -> 'Подверженная область на освоенной территории, доля' ... applying
#            ✔ done in 0.87s
#          CHANGE: sDensity: 'sDensity' -> 'Плотность очагов' ... applying
#            ✔ done in 0.86s
#          CHANGE: spTot: 'spTot' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.81s
#          CHANGE: spTotFrac: 'spTotFrac' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.84s
#          CHANGE: spLive: 'spLive' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.80s
#          CHANGE: spLiveFrac: 'spLiveFrac' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.84s
#          CHANGE: ieMeanTot: 'ieMeanTot' -> 'Средняя экстремальная интенсивность по МО' ... applying
#            ✔ done in 0.83s
#          CHANGE: ieMaxTot: 'ieMaxTot' -> 'Максимальная экстремальная интенсивность по МО' ... applying
#            ✔ done in 0.78s
#          CHANGE: ieMeanLive: 'ieMeanLive' -> 'Средняя экстремальная интенсивность на освоенной территории' ... applying
#            ✔ done in 0.91s
#          CHANGE: ieMaxLive: 'ieMaxLive' -> 'Максимальная экстремальная интенсивность  на освоенной территории' ... applying
#            ✔ done in 0.77s
#          CHANGE: itMeanTot: 'itMeanTot' -> 'Средняя типичная интенсивность по МО' ... applying
#            ✔ done in 0.73s
#          CHANGE: itMeanLive: 'itMeanLive' -> 'Средняя типичная интенсивность по освоенной площади' ... applying
#            ✔ done in 0.96s
#          CHANGE: iOverTot: 'iOverTot' -> 'Отклонение экстремума от нормы' ... applying
#            ✔ done in 0.87s
#          CHANGE: iOverLive: 'iOverLive' -> 'Отклонение экстремума от нормы' ... applying
#            ✔ done in 0.85s
#          ...processed 25/67 fields
#          CHANGE: fdMeanTot: 'fdMeanTot' -> 'Средняя повторяемость по МО дней с заданными условиями или' ... applying
#            ✔ done in 0.85s
#          CHANGE: fdMaxTot: 'fdMaxTot' -> 'Максимальная повторяемость дней по МО' ... applying
#            ✔ done in 0.75s
#          CHANGE: fdMeanLive: 'fdMeanLive' -> 'Средняя повторяемость на освоенной территории' ... applying
#            ✔ done in 0.83s
#          CHANGE: fdMaxLive: 'fdMaxLive' -> 'Максимальная повторяемость дней на освоенной территории' ... applying
#            ✔ done in 0.80s
#          CHANGE: hFxSTot: 'hFxSTot' -> 'Долевая территориальная нагрузка ОПЯ' ... applying
#            ✔ done in 0.81s
#          CHANGE: hFxSLive: 'hFxSLive' -> 'Долевая территориальная нагрузка ОПЯ по обжитой территории' ... applying
#            ✔ done in 0.94s
#          CHANGE: hNormTot: 'hNormTot' -> 'Градация опасности нормативная, вся территория' ... applying
#            ✔ done in 0.81s
#          CHANGE: hExpertTot: 'hExpertTot' -> 'Градация опасности экспертная, вся территория' ... applying
#            ✔ done in 0.93s
#          CHANGE: hNormLive: 'hNormLive' -> 'Градация опасности нормативная, освоенная территория' ... applying
#            ✔ done in 0.76s
#          CHANGE: hExpertLive: 'hExpertLive' -> 'Градация опасности экспертная, освоенная территория' ... applying
#            ✔ done in 1.05s
#          CHANGE: rNiNA_ho: 'rNiNA_ho' -> 'Число населенных пунктов в зоне ОПЯ' ... applying
#            ✔ done in 0.85s
#          CHANGE: rNF_ho: 'rNF_ho' -> 'Доля населенных пунктов в зоне ОПЯ' ... applying
#            ✔ done in 0.87s
#          CHANGE: rSiHA_ho: 'rSiHA_ho' -> 'Количество м2 жилья в зоне ОПЯ' ... applying
#            ✔ done in 0.75s
#          CHANGE: rSF_ho: 'rSF_ho' -> 'Доля м2 жилья в зоне ОПЯ' ... applying
#            ✔ done in 0.83s
#          CHANGE: rViHA_ho: 'rViHA_ho' -> 'Стоимость в опасной зоне указанного ОПЯ_Жильё' ... applying
#            ✔ done in 0.85s
#          CHANGE: rVaR_ho: 'rVaR_ho' -> 'Стоимость под риском указанного ОПЯ_Жильё' ... applying
#            ✔ done in 0.87s
#          CHANGE: rLiHA_ro: 'rLiHA_ro' -> 'Протяженность дорог в зоне ОПЯ' ... applying
#            ✔ done in 1.06s
#          CHANGE: rLF_ro: 'rLF_ro' -> 'Доля дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.83s
#          CHANGE: rViHA_ro: 'rViHA_ro' -> 'Стоимость в опасной зоне указанного ОПЯ_Автодороги' ... applying
#            ✔ done in 0.93s
#          CHANGE: rVaR_ro: 'rVaR_ro' -> 'Стоимость под риском указанного ОПЯ_Автодороги' ... applying
#            ✔ done in 0.92s
#          CHANGE: rLiHA_ra: 'rLiHA_ra' -> 'Протяженность дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.83s
#          CHANGE: rLF_ra: 'rLF_ra' -> 'Доля дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.89s
#          CHANGE: rViHA_ra: 'rViHA_ra' -> 'Стоимость в опасной зоне указанного ОПЯ_ЖД' ... applying
#            ✔ done in 0.95s
#          ...processed 50/67 fields
#          CHANGE: rVaR_ra: 'rVaR_ra' -> 'Стоимость под риском указанного ОПЯ_ЖД' ... applying
#            ✔ done in 0.88s
#          CHANGE: rSiHA_ag: 'rSiHA_ag' -> 'Площадь в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.80s
#          CHANGE: rSF_ag: 'rSF_ag' -> 'Доля площади в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.82s
#          CHANGE: rViHA_ag: 'rViHA_ag' -> 'Стоимость в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.93s
#          CHANGE: rVaR_ag: 'rVaR_ag' -> 'Стоимость под риском указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.82s
#          CHANGE: rSiHA_fo: 'rSiHA_fo' -> 'Площадь в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.93s
#          CHANGE: rSF_fo: 'rSF_fo' -> 'Доля площади в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 1.00s
#          CHANGE: rViHA_fo: 'rViHA_fo' -> 'Стоимость в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.77s
#          CHANGE: rVaR_fo: 'rVaR_fo' -> 'Стоимость под риском указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.94s
#          CHANGE: rSiHA_in: 'rSiHA_in' -> 'Площадь в опасной зоне указанного ОПЯ_пром' ... applying
#            ✔ done in 0.87s
#          CHANGE: rSF_in: 'rSF_in' -> 'Доля площади в опасной зоне указанного ОПЯ_пром' ... applying
#            ✔ done in 0.72s
#          CHANGE: rViHA_in: 'rViHA_in' -> 'Стоимость в опасной зоне указанного ОПЯ_промышленность' ... applying
#            ✔ done in 0.72s
#          CHANGE: rVaR_in: 'rVaR_in' -> 'Стоимость под риском указанного ОПЯ_промышленность' ... applying
#            ✔ done in 0.82s
#          CHANGE: rViHA_sum: 'rViHA_sum' -> 'Стоимость в опасной зоне указанного ОПЯ_все реципиенты' ... applying
#            ✔ done in 0.88s
#          CHANGE: rVaR_sum: 'rVaR_sum' -> 'Стоимость под риском указанного ОПЯ_все реципиенты' ... applying
#            ✔ done in 0.74s
#          CHANGE: rNiHA_pop: 'rNiHA_pop' -> 'Число жителей в опасной зоне' ... applying
#            ✔ done in 0.83s
#          CHANGE: rNF_pop: 'rNF_pop' -> 'Доля в опасной зоне от общего числа жителей' ... applying
#            ✔ done in 0.90s
#          CHANGE: rNaR_pop: 'rNaR_pop' -> 'Жители "под годовым риском"' ... applying
#            ✔ done in 0.86s
#        FC summary: processed=67, changed=63, skipped=4 | took 59.22s
#
# [FC 3/11] KHMAO_hazCold_MO -> C:\Users\User\Documents\ЦГД\KHMAO_RiskProfile_30-09-2025\KHMAO_RiskProfile\Default.gdb\risk\KHMAO_hazCold_MO
#        Fields (excl. OID/Geometry): 67
#          CHANGE: region: 'region' -> 'Регион' ... applying
#            ✔ done in 0.82s
#          CHANGE: MO: 'MO' -> 'МО' ... applying
#            ✔ done in 0.87s
#          CHANGE: area: 'area' -> 'Площадь общая' ... applying
#            ✔ done in 0.86s
#          CHANGE: areaLive: 'areaLive' -> 'Площадь освоенная' ... applying
#            ✔ done in 0.91s
#          CHANGE: areaLiveF: 'areaLiveF' -> 'Площадь освоенная, доля' ... applying
#            ✔ done in 0.77s
#          CHANGE: sTot: 'sTot' -> 'Подверженная область в МО' ... applying
#            ✔ done in 0.80s
#          CHANGE: sTotFrac: 'sTotFrac' -> 'Подверженная область в МО, доля' ... applying
#            ✔ done in 0.88s
#          CHANGE: sLive: 'sLive' -> 'Подверженная область на освоенной территории' ... applying
#            ✔ done in 0.83s
#          CHANGE: sLiveFrac: 'sLiveFrac' -> 'Подверженная область на освоенной территории, доля' ... applying
#            ✔ done in 0.74s
#          CHANGE: sDensity: 'sDensity' -> 'Плотность очагов' ... applying
#            ✔ done in 0.88s
#          CHANGE: spTot: 'spTot' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.83s
#          CHANGE: spTotFrac: 'spTotFrac' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.89s
#          CHANGE: spLive: 'spLive' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.95s
#          CHANGE: spLiveFrac: 'spLiveFrac' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.96s
#          CHANGE: ieMeanTot: 'ieMeanTot' -> 'Средняя экстремальная интенсивность по МО' ... applying
#            ✔ done in 0.91s
#          CHANGE: ieMaxTot: 'ieMaxTot' -> 'Максимальная экстремальная интенсивность по МО' ... applying
#            ✔ done in 0.85s
#          CHANGE: ieMeanLive: 'ieMeanLive' -> 'Средняя экстремальная интенсивность на освоенной территории' ... applying
#            ✔ done in 0.88s
#          CHANGE: ieMaxLive: 'ieMaxLive' -> 'Максимальная экстремальная интенсивность  на освоенной территории' ... applying
#            ✔ done in 0.95s
#          CHANGE: itMeanTot: 'itMeanTot' -> 'Средняя типичная интенсивность по МО' ... applying
#            ✔ done in 0.84s
#          CHANGE: itMeanLive: 'itMeanLive' -> 'Средняя типичная интенсивность по освоенной площади' ... applying
#            ✔ done in 0.94s
#          CHANGE: iOverTot: 'iOverTot' -> 'Отклонение экстремума от нормы' ... applying
#            ✔ done in 0.80s
#          CHANGE: iOverLive: 'iOverLive' -> 'Отклонение экстремума от нормы' ... applying
#            ✔ done in 0.86s
#          CHANGE: fdMeanTot: 'fdMeanTot' -> 'Средняя повторяемость по МО дней с заданными условиями или' ... applying
#            ✔ done in 0.85s
#          CHANGE: fdMaxTot: 'fdMaxTot' -> 'Максимальная повторяемость дней по МО' ... applying
#            ✔ done in 0.94s
#          ...processed 25/67 fields
#          CHANGE: fdMeanLive: 'fdMeanLive' -> 'Средняя повторяемость на освоенной территории' ... applying
#            ✔ done in 0.81s
#          CHANGE: fdMaxLive: 'fdMaxLive' -> 'Максимальная повторяемость дней на освоенной территории' ... applying
#            ✔ done in 0.70s
#          CHANGE: hFxSTot: 'hFxSTot' -> 'Долевая территориальная нагрузка ОПЯ' ... applying
#            ✔ done in 0.77s
#          CHANGE: hFxSLive: 'hFxSLive' -> 'Долевая территориальная нагрузка ОПЯ по обжитой территории' ... applying
#            ✔ done in 0.88s
#          CHANGE: hNormTot: 'hNormTot' -> 'Градация опасности нормативная, вся территория' ... applying
#            ✔ done in 0.92s
#          CHANGE: hExpertTot: 'hExpertTot' -> 'Градация опасности экспертная, вся территория' ... applying
#            ✔ done in 0.78s
#          CHANGE: hNormLive: 'hNormLive' -> 'Градация опасности нормативная, освоенная территория' ... applying
#            ✔ done in 0.89s
#          CHANGE: hExpertLive: 'hExpertLive' -> 'Градация опасности экспертная, освоенная территория' ... applying
#            ✔ done in 0.86s
#          CHANGE: rNiNA_ho: 'rNiNA_ho' -> 'Число населенных пунктов в зоне ОПЯ' ... applying
#            ✔ done in 0.86s
#          CHANGE: rNF_ho: 'rNF_ho' -> 'Доля населенных пунктов в зоне ОПЯ' ... applying
#            ✔ done in 0.88s
#          CHANGE: rSiHA_ho: 'rSiHA_ho' -> 'Количество м2 жилья в зоне ОПЯ' ... applying
#            ✔ done in 0.93s
#          CHANGE: rSF_ho: 'rSF_ho' -> 'Доля м2 жилья в зоне ОПЯ' ... applying
#            ✔ done in 0.83s
#          CHANGE: rViHA_ho: 'rViHA_ho' -> 'Стоимость в опасной зоне указанного ОПЯ_Жильё' ... applying
#            ✔ done in 0.71s
#          CHANGE: rVaR_ho: 'rVaR_ho' -> 'Стоимость под риском указанного ОПЯ_Жильё' ... applying
#            ✔ done in 0.70s
#          CHANGE: rLiHA_ro: 'rLiHA_ro' -> 'Протяженность дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.82s
#          CHANGE: rLF_ro: 'rLF_ro' -> 'Доля дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.88s
#          CHANGE: rViHA_ro: 'rViHA_ro' -> 'Стоимость в опасной зоне указанного ОПЯ_Автодороги' ... applying
#            ✔ done in 0.80s
#          CHANGE: rVaR_ro: 'rVaR_ro' -> 'Стоимость под риском указанного ОПЯ_Автодороги' ... applying
#            ✔ done in 0.87s
#          CHANGE: rLiHA_ra: 'rLiHA_ra' -> 'Протяженность дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.88s
#          CHANGE: rLF_ra: 'rLF_ra' -> 'Доля дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.99s
#          CHANGE: rViHA_ra: 'rViHA_ra' -> 'Стоимость в опасной зоне указанного ОПЯ_ЖД' ... applying
#            ✔ done in 0.96s
#          CHANGE: rVaR_ra: 'rVaR_ra' -> 'Стоимость под риском указанного ОПЯ_ЖД' ... applying
#            ✔ done in 0.94s
#          CHANGE: rSiHA_ag: 'rSiHA_ag' -> 'Площадь в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.88s
#          ...processed 50/67 fields
#          CHANGE: rSF_ag: 'rSF_ag' -> 'Доля площади в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.95s
#          CHANGE: rViHA_ag: 'rViHA_ag' -> 'Стоимость в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.83s
#          CHANGE: rVaR_ag: 'rVaR_ag' -> 'Стоимость под риском указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.85s
#          CHANGE: rSiHA_fo: 'rSiHA_fo' -> 'Площадь в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.83s
#          CHANGE: rSF_fo: 'rSF_fo' -> 'Доля площади в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.86s
#          CHANGE: rViHA_fo: 'rViHA_fo' -> 'Стоимость в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.85s
#          CHANGE: rVaR_fo: 'rVaR_fo' -> 'Стоимость под риском указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.85s
#          CHANGE: rSiHA_in: 'rSiHA_in' -> 'Площадь в опасной зоне указанного ОПЯ_пром' ... applying
#            ✔ done in 0.86s
#          CHANGE: rSF_in: 'rSF_in' -> 'Доля площади в опасной зоне указанного ОПЯ_пром' ... applying
#            ✔ done in 0.83s
#          CHANGE: rViHA_in: 'rViHA_in' -> 'Стоимость в опасной зоне указанного ОПЯ_промышленность' ... applying
#            ✔ done in 0.89s
#          CHANGE: rVaR_in: 'rVaR_in' -> 'Стоимость под риском указанного ОПЯ_промышленность' ... applying
#            ✔ done in 0.90s
#          CHANGE: rViHA_sum: 'rViHA_sum' -> 'Стоимость в опасной зоне указанного ОПЯ_все реципиенты' ... applying
#            ✔ done in 0.79s
#          CHANGE: rVaR_sum: 'rVaR_sum' -> 'Стоимость под риском указанного ОПЯ_все реципиенты' ... applying
#            ✔ done in 0.90s
#          CHANGE: rNiHA_pop: 'rNiHA_pop' -> 'Число жителей в опасной зоне' ... applying
#            ✔ done in 0.77s
#          CHANGE: rNF_pop: 'rNF_pop' -> 'Доля в опасной зоне от общего числа жителей' ... applying
#            ✔ done in 0.80s
#          CHANGE: rNaR_pop: 'rNaR_pop' -> 'Жители "под годовым риском"' ... applying
#            ✔ done in 0.77s
#        FC summary: processed=67, changed=63, skipped=4 | took 54.16s
#
# [FC 4/11] KHMAO_hazRain_MO -> C:\Users\User\Documents\ЦГД\KHMAO_RiskProfile_30-09-2025\KHMAO_RiskProfile\Default.gdb\risk\KHMAO_hazRain_MO
#        Fields (excl. OID/Geometry): 67
#          CHANGE: region: 'region' -> 'Регион' ... applying
#            ✔ done in 0.86s
#          CHANGE: MO: 'MO' -> 'МО' ... applying
#            ✔ done in 0.90s
#          CHANGE: area: 'area' -> 'Площадь общая' ... applying
#            ✔ done in 0.80s
#          CHANGE: areaLive: 'areaLive' -> 'Площадь освоенная' ... applying
#            ✔ done in 0.92s
#          CHANGE: areaLiveF: 'areaLiveF' -> 'Площадь освоенная, доля' ... applying
#            ✔ done in 0.92s
#          CHANGE: sTot: 'sTot' -> 'Подверженная область в МО' ... applying
#            ✔ done in 0.85s
#          CHANGE: sTotFrac: 'sTotFrac' -> 'Подверженная область в МО, доля' ... applying
#            ✔ done in 0.93s
#          CHANGE: sLive: 'sLive' -> 'Подверженная область на освоенной территории' ... applying
#            ✔ done in 0.77s
#          CHANGE: sLiveFrac: 'sLiveFrac' -> 'Подверженная область на освоенной территории, доля' ... applying
#            ✔ done in 0.84s
#          CHANGE: sDensity: 'sDensity' -> 'Плотность очагов' ... applying
#            ✔ done in 0.87s
#          CHANGE: spTot: 'spTot' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.87s
#          CHANGE: spTotFrac: 'spTotFrac' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.85s
#          CHANGE: spLive: 'spLive' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.91s
#          CHANGE: spLiveFrac: 'spLiveFrac' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.76s
#          CHANGE: ieMeanTot: 'ieMeanTot' -> 'Средняя экстремальная интенсивность по МО' ... applying
#            ✔ done in 0.95s
#          CHANGE: ieMaxTot: 'ieMaxTot' -> 'Максимальная экстремальная интенсивность по МО' ... applying
#            ✔ done in 0.88s
#          CHANGE: ieMeanLive: 'ieMeanLive' -> 'Средняя экстремальная интенсивность на освоенной территории' ... applying
#            ✔ done in 0.79s
#          CHANGE: ieMaxLive: 'ieMaxLive' -> 'Максимальная экстремальная интенсивность  на освоенной территории' ... applying
#            ✔ done in 0.89s
#          CHANGE: itMeanTot: 'itMeanTot' -> 'Средняя типичная интенсивность по МО' ... applying
#            ✔ done in 0.90s
#          CHANGE: itMeanLive: 'itMeanLive' -> 'Средняя типичная интенсивность по освоенной площади' ... applying
#            ✔ done in 0.87s
#          CHANGE: iOverTot: 'iOverTot' -> 'Отклонение экстремума от нормы' ... applying
#            ✔ done in 0.85s
#          CHANGE: iOverLive: 'iOverLive' -> 'Отклонение экстремума от нормы' ... applying
#            ✔ done in 0.89s
#          CHANGE: fdMeanTot: 'fdMeanTot' -> 'Средняя повторяемость по МО дней с заданными условиями или' ... applying
#            ✔ done in 0.77s
#          CHANGE: fdMaxTot: 'fdMaxTot' -> 'Максимальная повторяемость дней по МО' ... applying
#            ✔ done in 0.80s
#          ...processed 25/67 fields
#          CHANGE: fdMeanLive: 'fdMeanLive' -> 'Средняя повторяемость на освоенной территории' ... applying
#            ✔ done in 0.87s
#          CHANGE: fdMaxLive: 'fdMaxLive' -> 'Максимальная повторяемость дней на освоенной территории' ... applying
#            ✔ done in 0.75s
#          CHANGE: hFxSTot: 'hFxSTot' -> 'Долевая территориальная нагрузка ОПЯ' ... applying
#            ✔ done in 0.86s
#          CHANGE: hFxSLive: 'hFxSLive' -> 'Долевая территориальная нагрузка ОПЯ по обжитой территории' ... applying
#            ✔ done in 0.86s
#          CHANGE: hNormTot: 'hNormTot' -> 'Градация опасности нормативная, вся территория' ... applying
#            ✔ done in 0.84s
#          CHANGE: hExpertTot: 'hExpertTot' -> 'Градация опасности экспертная, вся территория' ... applying
#            ✔ done in 0.89s
#          CHANGE: hNormLive: 'hNormLive' -> 'Градация опасности нормативная, освоенная территория' ... applying
#            ✔ done in 0.92s
#          CHANGE: hExpertLive: 'hExpertLive' -> 'Градация опасности экспертная, освоенная территория' ... applying
#            ✔ done in 0.96s
#          CHANGE: rNiNA_ho: 'rNiNA_ho' -> 'Число населенных пунктов в зоне ОПЯ' ... applying
#            ✔ done in 0.80s
#          CHANGE: rNF_ho: 'rNF_ho' -> 'Доля населенных пунктов в зоне ОПЯ' ... applying
#            ✔ done in 1.11s
#          CHANGE: rSiHA_ho: 'rSiHA_ho' -> 'Количество м2 жилья в зоне ОПЯ' ... applying
#            ✔ done in 0.85s
#          CHANGE: rSF_ho: 'rSF_ho' -> 'Доля м2 жилья в зоне ОПЯ' ... applying
#            ✔ done in 0.91s
#          CHANGE: rViHA_ho: 'rViHA_ho' -> 'Стоимость в опасной зоне указанного ОПЯ_Жильё' ... applying
#            ✔ done in 0.87s
#          CHANGE: rVaR_ho: 'rVaR_ho' -> 'Стоимость под риском указанного ОПЯ_Жильё' ... applying
#            ✔ done in 0.83s
#          CHANGE: rLiHA_ro: 'rLiHA_ro' -> 'Протяженность дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.87s
#          CHANGE: rLF_ro: 'rLF_ro' -> 'Доля дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.87s
#          CHANGE: rViHA_ro: 'rViHA_ro' -> 'Стоимость в опасной зоне указанного ОПЯ_Автодороги' ... applying
#            ✔ done in 0.78s
#          CHANGE: rVaR_ro: 'rVaR_ro' -> 'Стоимость под риском указанного ОПЯ_Автодороги' ... applying
#            ✔ done in 0.94s
#          CHANGE: rLiHA_ra: 'rLiHA_ra' -> 'Протяженность дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.93s
#          CHANGE: rLF_ra: 'rLF_ra' -> 'Доля дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.85s
#          CHANGE: rViHA_ra: 'rViHA_ra' -> 'Стоимость в опасной зоне указанного ОПЯ_ЖД' ... applying
#            ✔ done in 0.81s
#          CHANGE: rVaR_ra: 'rVaR_ra' -> 'Стоимость под риском указанного ОПЯ_ЖД' ... applying
#            ✔ done in 0.88s
#          CHANGE: rSiHA_ag: 'rSiHA_ag' -> 'Площадь в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.92s
#          ...processed 50/67 fields
#          CHANGE: rSF_ag: 'rSF_ag' -> 'Доля площади в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.79s
#          CHANGE: rViHA_ag: 'rViHA_ag' -> 'Стоимость в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.73s
#          CHANGE: rVaR_ag: 'rVaR_ag' -> 'Стоимость под риском указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.82s
#          CHANGE: rSiHA_fo: 'rSiHA_fo' -> 'Площадь в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.84s
#          CHANGE: rSF_fo: 'rSF_fo' -> 'Доля площади в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.84s
#          CHANGE: rViHA_fo: 'rViHA_fo' -> 'Стоимость в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.80s
#          CHANGE: rVaR_fo: 'rVaR_fo' -> 'Стоимость под риском указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.85s
#          CHANGE: rSiHA_in: 'rSiHA_in' -> 'Площадь в опасной зоне указанного ОПЯ_пром' ... applying
#            ✔ done in 0.98s
#          CHANGE: rSF_in: 'rSF_in' -> 'Доля площади в опасной зоне указанного ОПЯ_пром' ... applying
#            ✔ done in 0.88s
#          CHANGE: rViHA_in: 'rViHA_in' -> 'Стоимость в опасной зоне указанного ОПЯ_промышленность' ... applying
#            ✔ done in 0.85s
#          CHANGE: rVaR_in: 'rVaR_in' -> 'Стоимость под риском указанного ОПЯ_промышленность' ... applying
#            ✔ done in 0.83s
#          CHANGE: rViHA_sum: 'rViHA_sum' -> 'Стоимость в опасной зоне указанного ОПЯ_все реципиенты' ... applying
#            ✔ done in 0.93s
#          CHANGE: rVaR_sum: 'rVaR_sum' -> 'Стоимость под риском указанного ОПЯ_все реципиенты' ... applying
#            ✔ done in 0.85s
#          CHANGE: rNiHA_pop: 'rNiHA_pop' -> 'Число жителей в опасной зоне' ... applying
#            ✔ done in 0.84s
#          CHANGE: rNF_pop: 'rNF_pop' -> 'Доля в опасной зоне от общего числа жителей' ... applying
#            ✔ done in 0.73s
#          CHANGE: rNaR_pop: 'rNaR_pop' -> 'Жители "под годовым риском"' ... applying
#            ✔ done in 0.88s
#        FC summary: processed=67, changed=63, skipped=4 | took 54.46s
#
# [FC 5/11] KHMAO_hazThunderstorm_MO -> C:\Users\User\Documents\ЦГД\KHMAO_RiskProfile_30-09-2025\KHMAO_RiskProfile\Default.gdb\risk\KHMAO_hazThunderstorm_MO
#        Fields (excl. OID/Geometry): 67
#          CHANGE: region: 'region' -> 'Регион' ... applying
#            ✔ done in 0.90s
#          CHANGE: MO: 'MO' -> 'МО' ... applying
#            ✔ done in 0.85s
#          CHANGE: area: 'area' -> 'Площадь общая' ... applying
#            ✔ done in 0.82s
#          CHANGE: areaLive: 'areaLive' -> 'Площадь освоенная' ... applying
#            ✔ done in 0.88s
#          CHANGE: areaLiveF: 'areaLiveF' -> 'Площадь освоенная, доля' ... applying
#            ✔ done in 0.77s
#          CHANGE: sTot: 'sTot' -> 'Подверженная область в МО' ... applying
#            ✔ done in 0.80s
#          CHANGE: sTotFrac: 'sTotFrac' -> 'Подверженная область в МО, доля' ... applying
#            ✔ done in 0.80s
#          CHANGE: sLive: 'sLive' -> 'Подверженная область на освоенной территории' ... applying
#            ✔ done in 0.77s
#          CHANGE: sLiveFrac: 'sLiveFrac' -> 'Подверженная область на освоенной территории, доля' ... applying
#            ✔ done in 0.82s
#          CHANGE: sDensity: 'sDensity' -> 'Плотность очагов' ... applying
#            ✔ done in 0.92s
#          CHANGE: spTot: 'spTot' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.80s
#          CHANGE: spTotFrac: 'spTotFrac' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.83s
#          CHANGE: spLive: 'spLive' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.92s
#          CHANGE: spLiveFrac: 'spLiveFrac' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.83s
#          CHANGE: ieMeanTot: 'ieMeanTot' -> 'Средняя экстремальная интенсивность по МО' ... applying
#            ✔ done in 0.85s
#          CHANGE: ieMaxTot: 'ieMaxTot' -> 'Максимальная экстремальная интенсивность по МО' ... applying
#            ✔ done in 0.82s
#          CHANGE: ieMeanLive: 'ieMeanLive' -> 'Средняя экстремальная интенсивность на освоенной территории' ... applying
#            ✔ done in 0.83s
#          CHANGE: ieMaxLive: 'ieMaxLive' -> 'Максимальная экстремальная интенсивность  на освоенной территории' ... applying
#            ✔ done in 0.85s
#          CHANGE: itMeanTot: 'itMeanTot' -> 'Средняя типичная интенсивность по МО' ... applying
#            ✔ done in 0.83s
#          CHANGE: itMeanLive: 'itMeanLive' -> 'Средняя типичная интенсивность по освоенной площади' ... applying
#            ✔ done in 0.82s
#          CHANGE: iOverTot: 'iOverTot' -> 'Отклонение экстремума от нормы' ... applying
#            ✔ done in 0.80s
#          CHANGE: iOverLive: 'iOverLive' -> 'Отклонение экстремума от нормы' ... applying
#            ✔ done in 0.85s
#          CHANGE: fdMeanTot: 'fdMeanTot' -> 'Средняя повторяемость по МО дней с заданными условиями или' ... applying
#            ✔ done in 0.81s
#          CHANGE: fdMaxTot: 'fdMaxTot' -> 'Максимальная повторяемость дней по МО' ... applying
#            ✔ done in 0.75s
#          ...processed 25/67 fields
#          CHANGE: fdMeanLive: 'fdMeanLive' -> 'Средняя повторяемость на освоенной территории' ... applying
#            ✔ done in 0.86s
#          CHANGE: fdMaxLive: 'fdMaxLive' -> 'Максимальная повторяемость дней на освоенной территории' ... applying
#            ✔ done in 1.04s
#          CHANGE: hFxSTot: 'hFxSTot' -> 'Долевая территориальная нагрузка ОПЯ' ... applying
#            ✔ done in 0.67s
#          CHANGE: hFxSLive: 'hFxSLive' -> 'Долевая территориальная нагрузка ОПЯ по обжитой территории' ... applying
#            ✔ done in 0.67s
#          CHANGE: hNormTot: 'hNormTot' -> 'Градация опасности нормативная, вся территория' ... applying
#            ✔ done in 0.78s
#          CHANGE: hExpertTot: 'hExpertTot' -> 'Градация опасности экспертная, вся территория' ... applying
#            ✔ done in 0.87s
#          CHANGE: hNormLive: 'hNormLive' -> 'Градация опасности нормативная, освоенная территория' ... applying
#            ✔ done in 0.78s
#          CHANGE: hExpertLive: 'hExpertLive' -> 'Градация опасности экспертная, освоенная территория' ... applying
#            ✔ done in 0.81s
#          CHANGE: rNiNA_ho: 'rNiNA_ho' -> 'Число населенных пунктов в зоне ОПЯ' ... applying
#            ✔ done in 0.72s
#          CHANGE: rNF_ho: 'rNF_ho' -> 'Доля населенных пунктов в зоне ОПЯ' ... applying
#            ✔ done in 0.91s
#          CHANGE: rSiHA_ho: 'rSiHA_ho' -> 'Количество м2 жилья в зоне ОПЯ' ... applying
#            ✔ done in 0.96s
#          CHANGE: rSF_ho: 'rSF_ho' -> 'Доля м2 жилья в зоне ОПЯ' ... applying
#            ✔ done in 0.98s
#          CHANGE: rViHA_ho: 'rViHA_ho' -> 'Стоимость в опасной зоне указанного ОПЯ_Жильё' ... applying
#            ✔ done in 0.77s
#          CHANGE: rVaR_ho: 'rVaR_ho' -> 'Стоимость под риском указанного ОПЯ_Жильё' ... applying
#            ✔ done in 0.82s
#          CHANGE: rLiHA_ro: 'rLiHA_ro' -> 'Протяженность дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.90s
#          CHANGE: rLF_ro: 'rLF_ro' -> 'Доля дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.98s
#          CHANGE: rViHA_ro: 'rViHA_ro' -> 'Стоимость в опасной зоне указанного ОПЯ_Автодороги' ... applying
#            ✔ done in 0.72s
#          CHANGE: rVaR_ro: 'rVaR_ro' -> 'Стоимость под риском указанного ОПЯ_Автодороги' ... applying
#            ✔ done in 0.84s
#          CHANGE: rLiHA_ra: 'rLiHA_ra' -> 'Протяженность дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.81s
#          CHANGE: rLF_ra: 'rLF_ra' -> 'Доля дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.81s
#          CHANGE: rViHA_ra: 'rViHA_ra' -> 'Стоимость в опасной зоне указанного ОПЯ_ЖД' ... applying
#            ✔ done in 0.76s
#          CHANGE: rVaR_ra: 'rVaR_ra' -> 'Стоимость под риском указанного ОПЯ_ЖД' ... applying
#            ✔ done in 0.82s
#          CHANGE: rSiHA_ag: 'rSiHA_ag' -> 'Площадь в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.83s
#          ...processed 50/67 fields
#          CHANGE: rSF_ag: 'rSF_ag' -> 'Доля площади в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.82s
#          CHANGE: rViHA_ag: 'rViHA_ag' -> 'Стоимость в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.78s
#          CHANGE: rVaR_ag: 'rVaR_ag' -> 'Стоимость под риском указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.74s
#          CHANGE: rSiHA_fo: 'rSiHA_fo' -> 'Площадь в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.90s
#          CHANGE: rSF_fo: 'rSF_fo' -> 'Доля площади в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.87s
#          CHANGE: rViHA_fo: 'rViHA_fo' -> 'Стоимость в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.90s
#          CHANGE: rVaR_fo: 'rVaR_fo' -> 'Стоимость под риском указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.73s
#          CHANGE: rSiHA_in: 'rSiHA_in' -> 'Площадь в опасной зоне указанного ОПЯ_пром' ... applying
#            ✔ done in 0.80s
#          CHANGE: rSF_in: 'rSF_in' -> 'Доля площади в опасной зоне указанного ОПЯ_пром' ... applying
#            ✔ done in 0.81s
#          CHANGE: rViHA_in: 'rViHA_in' -> 'Стоимость в опасной зоне указанного ОПЯ_промышленность' ... applying
#            ✔ done in 0.73s
#          CHANGE: rVaR_in: 'rVaR_in' -> 'Стоимость под риском указанного ОПЯ_промышленность' ... applying
#            ✔ done in 0.81s
#          CHANGE: rViHA_sum: 'rViHA_sum' -> 'Стоимость в опасной зоне указанного ОПЯ_все реципиенты' ... applying
#            ✔ done in 0.84s
#          CHANGE: rVaR_sum: 'rVaR_sum' -> 'Стоимость под риском указанного ОПЯ_все реципиенты' ... applying
#            ✔ done in 0.90s
#          CHANGE: rNiHA_pop: 'rNiHA_pop' -> 'Число жителей в опасной зоне' ... applying
#            ✔ done in 0.88s
#          CHANGE: rNF_pop: 'rNF_pop' -> 'Доля в опасной зоне от общего числа жителей' ... applying
#            ✔ done in 0.83s
#          CHANGE: rNaR_pop: 'rNaR_pop' -> 'Жители "под годовым риском"' ... applying
#            ✔ done in 0.77s
#        FC summary: processed=67, changed=63, skipped=4 | took 52.49s
#
# [FC 6/11] KHMAO_hazFreez5_MO -> C:\Users\User\Documents\ЦГД\KHMAO_RiskProfile_30-09-2025\KHMAO_RiskProfile\Default.gdb\risk\KHMAO_hazFreez5_MO
#        Fields (excl. OID/Geometry): 67
#          CHANGE: region: 'region' -> 'Регион' ... applying
#            ✔ done in 0.79s
#          CHANGE: MO: 'MO' -> 'МО' ... applying
#            ✔ done in 0.85s
#          CHANGE: area: 'area' -> 'Площадь общая' ... applying
#            ✔ done in 0.87s
#          CHANGE: areaLive: 'areaLive' -> 'Площадь освоенная' ... applying
#            ✔ done in 0.78s
#          CHANGE: areaLiveF: 'areaLiveF' -> 'Площадь освоенная, доля' ... applying
#            ✔ done in 0.79s
#          CHANGE: sTot: 'sTot' -> 'Подверженная область в МО' ... applying
#            ✔ done in 0.86s
#          CHANGE: sTotFrac: 'sTotFrac' -> 'Подверженная область в МО, доля' ... applying
#            ✔ done in 0.86s
#          CHANGE: sLive: 'sLive' -> 'Подверженная область на освоенной территории' ... applying
#            ✔ done in 0.79s
#          CHANGE: sLiveFrac: 'sLiveFrac' -> 'Подверженная область на освоенной территории, доля' ... applying
#            ✔ done in 0.83s
#          CHANGE: sDensity: 'sDensity' -> 'Плотность очагов' ... applying
#            ✔ done in 0.81s
#          CHANGE: spTot: 'spTot' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.78s
#          CHANGE: spTotFrac: 'spTotFrac' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.81s
#          CHANGE: spLive: 'spLive' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.82s
#          CHANGE: spLiveFrac: 'spLiveFrac' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.86s
#          CHANGE: ieMeanTot: 'ieMeanTot' -> 'Средняя экстремальная интенсивность по МО' ... applying
#            ✔ done in 0.78s
#          CHANGE: ieMaxTot: 'ieMaxTot' -> 'Максимальная экстремальная интенсивность по МО' ... applying
#            ✔ done in 0.96s
#          CHANGE: ieMeanLive: 'ieMeanLive' -> 'Средняя экстремальная интенсивность на освоенной территории' ... applying
#            ✔ done in 0.71s
#          CHANGE: ieMaxLive: 'ieMaxLive' -> 'Максимальная экстремальная интенсивность  на освоенной территории' ... applying
#            ✔ done in 0.84s
#          CHANGE: itMeanTot: 'itMeanTot' -> 'Средняя типичная интенсивность по МО' ... applying
#            ✔ done in 0.90s
#          CHANGE: itMeanLive: 'itMeanLive' -> 'Средняя типичная интенсивность по освоенной площади' ... applying
#            ✔ done in 0.82s
#          CHANGE: iOverTot: 'iOverTot' -> 'Отклонение экстремума от нормы' ... applying
#            ✔ done in 0.79s
#          CHANGE: iOverLive: 'iOverLive' -> 'Отклонение экстремума от нормы' ... applying
#            ✔ done in 0.81s
#          CHANGE: fdMeanTot: 'fdMeanTot' -> 'Средняя повторяемость по МО дней с заданными условиями или' ... applying
#            ✔ done in 0.83s
#          CHANGE: fdMaxTot: 'fdMaxTot' -> 'Максимальная повторяемость дней по МО' ... applying
#            ✔ done in 0.80s
#          ...processed 25/67 fields
#          CHANGE: fdMeanLive: 'fdMeanLive' -> 'Средняя повторяемость на освоенной территории' ... applying
#            ✔ done in 0.72s
#          CHANGE: fdMaxLive: 'fdMaxLive' -> 'Максимальная повторяемость дней на освоенной территории' ... applying
#            ✔ done in 0.80s
#          CHANGE: hFxSTot: 'hFxSTot' -> 'Долевая территориальная нагрузка ОПЯ' ... applying
#            ✔ done in 0.93s
#          CHANGE: hFxSLive: 'hFxSLive' -> 'Долевая территориальная нагрузка ОПЯ по обжитой территории' ... applying
#            ✔ done in 0.89s
#          CHANGE: hNormTot: 'hNormTot' -> 'Градация опасности нормативная, вся территория' ... applying
#            ✔ done in 0.82s
#          CHANGE: hExpertTot: 'hExpertTot' -> 'Градация опасности экспертная, вся территория' ... applying
#            ✔ done in 0.82s
#          CHANGE: hNormLive: 'hNormLive' -> 'Градация опасности нормативная, освоенная территория' ... applying
#            ✔ done in 0.87s
#          CHANGE: hExpertLive: 'hExpertLive' -> 'Градация опасности экспертная, освоенная территория' ... applying
#            ✔ done in 0.86s
#          CHANGE: rNiNA_ho: 'rNiNA_ho' -> 'Число населенных пунктов в зоне ОПЯ' ... applying
#            ✔ done in 0.75s
#          CHANGE: rNF_ho: 'rNF_ho' -> 'Доля населенных пунктов в зоне ОПЯ' ... applying
#            ✔ done in 0.77s
#          CHANGE: rSiHA_ho: 'rSiHA_ho' -> 'Количество м2 жилья в зоне ОПЯ' ... applying
#            ✔ done in 0.81s
#          CHANGE: rSF_ho: 'rSF_ho' -> 'Доля м2 жилья в зоне ОПЯ' ... applying
#            ✔ done in 0.83s
#          CHANGE: rViHA_ho: 'rViHA_ho' -> 'Стоимость в опасной зоне указанного ОПЯ_Жильё' ... applying
#            ✔ done in 0.87s
#          CHANGE: rVaR_ho: 'rVaR_ho' -> 'Стоимость под риском указанного ОПЯ_Жильё' ... applying
#            ✔ done in 0.76s
#          CHANGE: rLiHA_ro: 'rLiHA_ro' -> 'Протяженность дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.82s
#          CHANGE: rLF_ro: 'rLF_ro' -> 'Доля дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.83s
#          CHANGE: rViHA_ro: 'rViHA_ro' -> 'Стоимость в опасной зоне указанного ОПЯ_Автодороги' ... applying
#            ✔ done in 0.86s
#          CHANGE: rVaR_ro: 'rVaR_ro' -> 'Стоимость под риском указанного ОПЯ_Автодороги' ... applying
#            ✔ done in 0.80s
#          CHANGE: rLiHA_ra: 'rLiHA_ra' -> 'Протяженность дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.77s
#          CHANGE: rLF_ra: 'rLF_ra' -> 'Доля дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.88s
#          CHANGE: rViHA_ra: 'rViHA_ra' -> 'Стоимость в опасной зоне указанного ОПЯ_ЖД' ... applying
#            ✔ done in 0.86s
#          CHANGE: rVaR_ra: 'rVaR_ra' -> 'Стоимость под риском указанного ОПЯ_ЖД' ... applying
#            ✔ done in 0.73s
#          CHANGE: rSiHA_ag: 'rSiHA_ag' -> 'Площадь в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.85s
#          ...processed 50/67 fields
#          CHANGE: rSF_ag: 'rSF_ag' -> 'Доля площади в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.80s
#          CHANGE: rViHA_ag: 'rViHA_ag' -> 'Стоимость в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.80s
#          CHANGE: rVaR_ag: 'rVaR_ag' -> 'Стоимость под риском указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.67s
#          CHANGE: rSiHA_fo: 'rSiHA_fo' -> 'Площадь в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.74s
#          CHANGE: rSF_fo: 'rSF_fo' -> 'Доля площади в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.85s
#          CHANGE: rViHA_fo: 'rViHA_fo' -> 'Стоимость в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.80s
#          CHANGE: rVaR_fo: 'rVaR_fo' -> 'Стоимость под риском указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.87s
#          CHANGE: rSiHA_in: 'rSiHA_in' -> 'Площадь в опасной зоне указанного ОПЯ_пром' ... applying
#            ✔ done in 0.81s
#          CHANGE: rSF_in: 'rSF_in' -> 'Доля площади в опасной зоне указанного ОПЯ_пром' ... applying
#            ✔ done in 0.84s
#          CHANGE: rViHA_in: 'rViHA_in' -> 'Стоимость в опасной зоне указанного ОПЯ_промышленность' ... applying
#            ✔ done in 0.88s
#          CHANGE: rVaR_in: 'rVaR_in' -> 'Стоимость под риском указанного ОПЯ_промышленность' ... applying
#            ✔ done in 0.91s
#          CHANGE: rViHA_sum: 'rViHA_sum' -> 'Стоимость в опасной зоне указанного ОПЯ_все реципиенты' ... applying
#            ✔ done in 0.83s
#          CHANGE: rVaR_sum: 'rVaR_sum' -> 'Стоимость под риском указанного ОПЯ_все реципиенты' ... applying
#            ✔ done in 0.84s
#          CHANGE: rNiHA_pop: 'rNiHA_pop' -> 'Число жителей в опасной зоне' ... applying
#            ✔ done in 0.92s
#          CHANGE: rNF_pop: 'rNF_pop' -> 'Доля в опасной зоне от общего числа жителей' ... applying
#            ✔ done in 0.93s
#          CHANGE: rNaR_pop: 'rNaR_pop' -> 'Жители "под годовым риском"' ... applying
#            ✔ done in 0.86s
#        FC summary: processed=67, changed=63, skipped=4 | took 52.22s
#
# [FC 7/11] KHMAO_hazHail_MO -> C:\Users\User\Documents\ЦГД\KHMAO_RiskProfile_30-09-2025\KHMAO_RiskProfile\Default.gdb\risk\KHMAO_hazHail_MO
#        Fields (excl. OID/Geometry): 67
#          CHANGE: region: 'region' -> 'Регион' ... applying
#            ✔ done in 0.75s
#          CHANGE: MO: 'MO' -> 'МО' ... applying
#            ✔ done in 0.90s
#          CHANGE: area: 'area' -> 'Площадь общая' ... applying
#            ✔ done in 0.84s
#          CHANGE: areaLive: 'areaLive' -> 'Площадь освоенная' ... applying
#            ✔ done in 0.84s
#          CHANGE: areaLiveF: 'areaLiveF' -> 'Площадь освоенная, доля' ... applying
#            ✔ done in 0.76s
#          CHANGE: sTot: 'sTot' -> 'Подверженная область в МО' ... applying
#            ✔ done in 0.81s
#          CHANGE: sTotFrac: 'sTotFrac' -> 'Подверженная область в МО, доля' ... applying
#            ✔ done in 0.86s
#          CHANGE: sLive: 'sLive' -> 'Подверженная область на освоенной территории' ... applying
#            ✔ done in 0.80s
#          CHANGE: sLiveFrac: 'sLiveFrac' -> 'Подверженная область на освоенной территории, доля' ... applying
#            ✔ done in 0.73s
#          CHANGE: sDensity: 'sDensity' -> 'Плотность очагов' ... applying
#            ✔ done in 0.88s
#          CHANGE: spTot: 'spTot' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.87s
#          CHANGE: spTotFrac: 'spTotFrac' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.80s
#          CHANGE: spLive: 'spLive' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.85s
#          CHANGE: spLiveFrac: 'spLiveFrac' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.74s
#          CHANGE: ieMeanTot: 'ieMeanTot' -> 'Средняя экстремальная интенсивность по МО' ... applying
#            ✔ done in 0.88s
#          CHANGE: ieMaxTot: 'ieMaxTot' -> 'Максимальная экстремальная интенсивность по МО' ... applying
#            ✔ done in 0.78s
#          CHANGE: ieMeanLive: 'ieMeanLive' -> 'Средняя экстремальная интенсивность на освоенной территории' ... applying
#            ✔ done in 0.83s
#          CHANGE: ieMaxLive: 'ieMaxLive' -> 'Максимальная экстремальная интенсивность  на освоенной территории' ... applying
#            ✔ done in 0.79s
#          CHANGE: itMeanTot: 'itMeanTot' -> 'Средняя типичная интенсивность по МО' ... applying
#            ✔ done in 0.74s
#          CHANGE: itMeanLive: 'itMeanLive' -> 'Средняя типичная интенсивность по освоенной площади' ... applying
#            ✔ done in 0.80s
#          CHANGE: iOverTot: 'iOverTot' -> 'Отклонение экстремума от нормы' ... applying
#            ✔ done in 0.90s
#          CHANGE: iOverLive: 'iOverLive' -> 'Отклонение экстремума от нормы' ... applying
#            ✔ done in 0.78s
#          CHANGE: fdMeanTot: 'fdMeanTot' -> 'Средняя повторяемость по МО дней с заданными условиями или' ... applying
#            ✔ done in 0.85s
#          CHANGE: fdMaxTot: 'fdMaxTot' -> 'Максимальная повторяемость дней по МО' ... applying
#            ✔ done in 0.93s
#          ...processed 25/67 fields
#          CHANGE: fdMeanLive: 'fdMeanLive' -> 'Средняя повторяемость на освоенной территории' ... applying
#            ✔ done in 0.72s
#          CHANGE: fdMaxLive: 'fdMaxLive' -> 'Максимальная повторяемость дней на освоенной территории' ... applying
#            ✔ done in 0.87s
#          CHANGE: hFxSTot: 'hFxSTot' -> 'Долевая территориальная нагрузка ОПЯ' ... applying
#            ✔ done in 0.75s
#          CHANGE: hFxSLive: 'hFxSLive' -> 'Долевая территориальная нагрузка ОПЯ по обжитой территории' ... applying
#            ✔ done in 0.90s
#          CHANGE: hNormTot: 'hNormTot' -> 'Градация опасности нормативная, вся территория' ... applying
#            ✔ done in 0.81s
#          CHANGE: hExpertTot: 'hExpertTot' -> 'Градация опасности экспертная, вся территория' ... applying
#            ✔ done in 0.82s
#          CHANGE: hNormLive: 'hNormLive' -> 'Градация опасности нормативная, освоенная территория' ... applying
#            ✔ done in 0.85s
#          CHANGE: hExpertLive: 'hExpertLive' -> 'Градация опасности экспертная, освоенная территория' ... applying
#            ✔ done in 0.77s
#          CHANGE: rNiNA_ho: 'rNiNA_ho' -> 'Число населенных пунктов в зоне ОПЯ' ... applying
#            ✔ done in 0.90s
#          CHANGE: rNF_ho: 'rNF_ho' -> 'Доля населенных пунктов в зоне ОПЯ' ... applying
#            ✔ done in 0.91s
#          CHANGE: rSiHA_ho: 'rSiHA_ho' -> 'Количество м2 жилья в зоне ОПЯ' ... applying
#            ✔ done in 0.77s
#          CHANGE: rSF_ho: 'rSF_ho' -> 'Доля м2 жилья в зоне ОПЯ' ... applying
#            ✔ done in 0.80s
#          CHANGE: rViHA_ho: 'rViHA_ho' -> 'Стоимость в опасной зоне указанного ОПЯ_Жильё' ... applying
#            ✔ done in 0.82s
#          CHANGE: rVaR_ho: 'rVaR_ho' -> 'Стоимость под риском указанного ОПЯ_Жильё' ... applying
#            ✔ done in 0.83s
#          CHANGE: rLiHA_ro: 'rLiHA_ro' -> 'Протяженность дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.75s
#          CHANGE: rLF_ro: 'rLF_ro' -> 'Доля дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.73s
#          CHANGE: rViHA_ro: 'rViHA_ro' -> 'Стоимость в опасной зоне указанного ОПЯ_Автодороги' ... applying
#            ✔ done in 0.83s
#          CHANGE: rVaR_ro: 'rVaR_ro' -> 'Стоимость под риском указанного ОПЯ_Автодороги' ... applying
#            ✔ done in 0.77s
#          CHANGE: rLiHA_ra: 'rLiHA_ra' -> 'Протяженность дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.90s
#          CHANGE: rLF_ra: 'rLF_ra' -> 'Доля дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.62s
#          CHANGE: rViHA_ra: 'rViHA_ra' -> 'Стоимость в опасной зоне указанного ОПЯ_ЖД' ... applying
#            ✔ done in 0.94s
#          CHANGE: rVaR_ra: 'rVaR_ra' -> 'Стоимость под риском указанного ОПЯ_ЖД' ... applying
#            ✔ done in 0.89s
#          CHANGE: rSiHA_ag: 'rSiHA_ag' -> 'Площадь в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.80s
#          ...processed 50/67 fields
#          CHANGE: rSF_ag: 'rSF_ag' -> 'Доля площади в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.70s
#          CHANGE: rViHA_ag: 'rViHA_ag' -> 'Стоимость в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.79s
#          CHANGE: rVaR_ag: 'rVaR_ag' -> 'Стоимость под риском указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.86s
#          CHANGE: rSiHA_fo: 'rSiHA_fo' -> 'Площадь в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.74s
#          CHANGE: rSF_fo: 'rSF_fo' -> 'Доля площади в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.81s
#          CHANGE: rViHA_fo: 'rViHA_fo' -> 'Стоимость в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.85s
#          CHANGE: rVaR_fo: 'rVaR_fo' -> 'Стоимость под риском указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.95s
#          CHANGE: rSiHA_in: 'rSiHA_in' -> 'Площадь в опасной зоне указанного ОПЯ_пром' ... applying
#            ✔ done in 0.88s
#          CHANGE: rSF_in: 'rSF_in' -> 'Доля площади в опасной зоне указанного ОПЯ_пром' ... applying
#            ✔ done in 0.94s
# ...
#            ✔ done in 0.99s
#          CHANGE: spTot: 'spTot' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.93s
#          CHANGE: spTotFrac: 'spTotFrac' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.94s
#          CHANGE: spLive: 'spLive' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 1.00s
#          CHANGE: spLiveFrac: 'spLiveFrac' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.93s
#          CHANGE: ieMeanTot: 'ieMeanTot' -> 'Средняя экстремальная интенсивность по МО' ... applying
#            ✔ done in 0.90s
#          CHANGE: ieMaxTot: 'ieMaxTot' -> 'Максимальная экстремальная интенсивность по МО' ... applying
#            ✔ done in 0.88s
#          CHANGE: ieMeanLive: 'ieMeanLive' -> 'Средняя экстремальная интенсивность на освоенной территории' ... applying
#            ✔ done in 1.03s
#          CHANGE: ieMaxLive: 'ieMaxLive' -> 'Максимальная экстремальная интенсивность  на освоенной территории' ... applying
#            ✔ done in 0.82s
#          CHANGE: itMeanTot: 'itMeanTot' -> 'Средняя типичная интенсивность по МО' ... applying
#            ✔ done in 0.87s
#          CHANGE: itMeanLive: 'itMeanLive' -> 'Средняя типичная интенсивность по освоенной площади' ... applying
#            ✔ done in 0.85s
#          CHANGE: iOverTot: 'iOverTot' -> 'Отклонение экстремума от нормы' ... applying
#            ✔ done in 0.94s
#          CHANGE: iOverLive: 'iOverLive' -> 'Отклонение экстремума от нормы' ... applying
#            ✔ done in 0.86s
#          CHANGE: fdMeanTot: 'fdMeanTot' -> 'Средняя повторяемость по МО дней с заданными условиями или' ... applying
#            ✔ done in 0.81s
#          CHANGE: fdMaxTot: 'fdMaxTot' -> 'Максимальная повторяемость дней по МО' ... applying
#            ✔ done in 0.93s
#          ...processed 25/67 fields
#          CHANGE: fdMeanLive: 'fdMeanLive' -> 'Средняя повторяемость на освоенной территории' ... applying
#            ✔ done in 0.92s
#          CHANGE: fdMaxLive: 'fdMaxLive' -> 'Максимальная повторяемость дней на освоенной территории' ... applying
#            ✔ done in 0.90s
#          CHANGE: hFxSTot: 'hFxSTot' -> 'Долевая территориальная нагрузка ОПЯ' ... applying
#            ✔ done in 0.96s
#          CHANGE: hFxSLive: 'hFxSLive' -> 'Долевая территориальная нагрузка ОПЯ по обжитой территории' ... applying
#            ✔ done in 0.87s
#          CHANGE: hNormTot: 'hNormTot' -> 'Градация опасности нормативная, вся территория' ... applying
#            ✔ done in 0.94s
#          CHANGE: hExpertTot: 'hExpertTot' -> 'Градация опасности экспертная, вся территория' ... applying
#            ✔ done in 0.90s
#          CHANGE: hNormLive: 'hNormLive' -> 'Градация опасности нормативная, освоенная территория' ... applying
#            ✔ done in 0.87s
#          CHANGE: hExpertLive: 'hExpertLive' -> 'Градация опасности экспертная, освоенная территория' ... applying
#            ✔ done in 0.86s
#          CHANGE: rNiNA_ho: 'rNiNA_ho' -> 'Число населенных пунктов в зоне ОПЯ' ... applying
#            ✔ done in 0.94s
#          CHANGE: rNF_ho: 'rNF_ho' -> 'Доля населенных пунктов в зоне ОПЯ' ... applying
#            ✔ done in 0.93s
#          CHANGE: rSiHA_ho: 'rSiHA_ho' -> 'Количество м2 жилья в зоне ОПЯ' ... applying
#            ✔ done in 0.94s
#          CHANGE: rSF_ho: 'rSF_ho' -> 'Доля м2 жилья в зоне ОПЯ' ... applying
#            ✔ done in 0.88s
#          CHANGE: rViHA_ho: 'rViHA_ho' -> 'Стоимость в опасной зоне указанного ОПЯ_Жильё' ... applying
#            ✔ done in 0.92s
#          CHANGE: rVaR_ho: 'rVaR_ho' -> 'Стоимость под риском указанного ОПЯ_Жильё' ... applying
#            ✔ done in 0.85s
#          CHANGE: rLiHA_ro: 'rLiHA_ro' -> 'Протяженность дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.89s
#          CHANGE: rLF_ro: 'rLF_ro' -> 'Доля дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.97s
#          CHANGE: rViHA_ro: 'rViHA_ro' -> 'Стоимость в опасной зоне указанного ОПЯ_Автодороги' ... applying
#            ✔ done in 1.02s
#          CHANGE: rVaR_ro: 'rVaR_ro' -> 'Стоимость под риском указанного ОПЯ_Автодороги' ... applying
#            ✔ done in 0.86s
#          CHANGE: rLiHA_ra: 'rLiHA_ra' -> 'Протяженность дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.81s
#          CHANGE: rLF_ra: 'rLF_ra' -> 'Доля дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.93s
#          CHANGE: rViHA_ra: 'rViHA_ra' -> 'Стоимость в опасной зоне указанного ОПЯ_ЖД' ... applying
#            ✔ done in 0.92s
#          CHANGE: rVaR_ra: 'rVaR_ra' -> 'Стоимость под риском указанного ОПЯ_ЖД' ... applying
#            ✔ done in 0.90s
#          CHANGE: rSiHA_ag: 'rSiHA_ag' -> 'Площадь в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.86s
#          ...processed 50/67 fields
#          CHANGE: rSF_ag: 'rSF_ag' -> 'Доля площади в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.91s
#          CHANGE: rViHA_ag: 'rViHA_ag' -> 'Стоимость в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.98s
#          CHANGE: rVaR_ag: 'rVaR_ag' -> 'Стоимость под риском указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.80s
#          CHANGE: rSiHA_fo: 'rSiHA_fo' -> 'Площадь в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.99s
#          CHANGE: rSF_fo: 'rSF_fo' -> 'Доля площади в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.82s
#          CHANGE: rViHA_fo: 'rViHA_fo' -> 'Стоимость в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.98s
#          CHANGE: rVaR_fo: 'rVaR_fo' -> 'Стоимость под риском указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.88s
#          CHANGE: rSiHA_in: 'rSiHA_in' -> 'Площадь в опасной зоне указанного ОПЯ_пром' ... applying
#            ✔ done in 0.92s
#          CHANGE: rSF_in: 'rSF_in' -> 'Доля площади в опасной зоне указанного ОПЯ_пром' ... applying
#            ✔ done in 0.81s
#          CHANGE: rViHA_in: 'rViHA_in' -> 'Стоимость в опасной зоне указанного ОПЯ_промышленность' ... applying
#            ✔ done in 0.94s
#          CHANGE: rVaR_in: 'rVaR_in' -> 'Стоимость под риском указанного ОПЯ_промышленность' ... applying
#            ✔ done in 0.91s
#          CHANGE: rViHA_sum: 'rViHA_sum' -> 'Стоимость в опасной зоне указанного ОПЯ_все реципиенты' ... applying
#            ✔ done in 0.81s
#          CHANGE: rVaR_sum: 'rVaR_sum' -> 'Стоимость под риском указанного ОПЯ_все реципиенты' ... applying
#            ✔ done in 0.83s
#          CHANGE: rNiHA_pop: 'rNiHA_pop' -> 'Число жителей в опасной зоне' ... applying
#            ✔ done in 0.86s
#          CHANGE: rNF_pop: 'rNF_pop' -> 'Доля в опасной зоне от общего числа жителей' ... applying
#            ✔ done in 0.86s
#          CHANGE: rNaR_pop: 'rNaR_pop' -> 'Жители "под годовым риском"' ... applying
#            ✔ done in 0.90s
#        FC summary: processed=67, changed=63, skipped=4 | took 57.27s
#
# [FC 11/11] KHMAO_hazWildfire_MO -> C:\Users\User\Documents\ЦГД\KHMAO_RiskProfile_30-09-2025\KHMAO_RiskProfile\Default.gdb\risk\KHMAO_hazWildfire_MO
#        Fields (excl. OID/Geometry): 67
#          CHANGE: region: 'region' -> 'Регион' ... applying
#            ✔ done in 0.73s
#          CHANGE: MO: 'MO' -> 'МО' ... applying
#            ✔ done in 0.89s
#          CHANGE: area: 'area' -> 'Площадь общая' ... applying
#            ✔ done in 0.91s
#          CHANGE: areaLive: 'areaLive' -> 'Площадь освоенная' ... applying
#            ✔ done in 0.89s
#          CHANGE: areaLiveF: 'areaLiveF' -> 'Площадь освоенная, доля' ... applying
#            ✔ done in 0.86s
#          CHANGE: sTot: 'sTot' -> 'Подверженная область в МО' ... applying
#            ✔ done in 1.02s
#          CHANGE: sTotFrac: 'sTotFrac' -> 'Подверженная область в МО, доля' ... applying
#            ✔ done in 0.83s
#          CHANGE: sLive: 'sLive' -> 'Подверженная область на освоенной территории' ... applying
#            ✔ done in 0.83s
#          CHANGE: sLiveFrac: 'sLiveFrac' -> 'Подверженная область на освоенной территории, доля' ... applying
#            ✔ done in 0.89s
#          CHANGE: sDensity: 'sDensity' -> 'Плотность очагов' ... applying
#            ✔ done in 0.92s
#          CHANGE: spTot: 'spTot' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.82s
#          CHANGE: spTotFrac: 'spTotFrac' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.87s
#          CHANGE: spLive: 'spLive' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 1.08s
#          CHANGE: spLiveFrac: 'spLiveFrac' -> 'Потенциально подверженная область' ... applying
#            ✔ done in 0.90s
#          CHANGE: ieMeanTot: 'ieMeanTot' -> 'Средняя экстремальная интенсивность по МО' ... applying
#            ✔ done in 0.80s
#          CHANGE: ieMaxTot: 'ieMaxTot' -> 'Максимальная экстремальная интенсивность по МО' ... applying
#            ✔ done in 0.73s
#          CHANGE: ieMeanLive: 'ieMeanLive' -> 'Средняя экстремальная интенсивность на освоенной территории' ... applying
#            ✔ done in 0.82s
#          CHANGE: ieMaxLive: 'ieMaxLive' -> 'Максимальная экстремальная интенсивность  на освоенной территории' ... applying
#            ✔ done in 0.96s
#          CHANGE: itMeanTot: 'itMeanTot' -> 'Средняя типичная интенсивность по МО' ... applying
#            ✔ done in 0.82s
#          CHANGE: itMeanLive: 'itMeanLive' -> 'Средняя типичная интенсивность по освоенной площади' ... applying
#            ✔ done in 0.87s
#          CHANGE: iOverTot: 'iOverTot' -> 'Отклонение экстремума от нормы' ... applying
#            ✔ done in 0.81s
#          CHANGE: iOverLive: 'iOverLive' -> 'Отклонение экстремума от нормы' ... applying
#            ✔ done in 0.82s
#          CHANGE: fdMeanTot: 'fdMeanTot' -> 'Средняя повторяемость по МО дней с заданными условиями или' ... applying
#            ✔ done in 0.90s
#          CHANGE: fdMaxTot: 'fdMaxTot' -> 'Максимальная повторяемость дней по МО' ... applying
#            ✔ done in 0.85s
#          ...processed 25/67 fields
#          CHANGE: fdMeanLive: 'fdMeanLive' -> 'Средняя повторяемость на освоенной территории' ... applying
#            ✔ done in 0.89s
#          CHANGE: fdMaxLive: 'fdMaxLive' -> 'Максимальная повторяемость дней на освоенной территории' ... applying
#            ✔ done in 0.88s
#          CHANGE: hFxSTot: 'hFxSTot' -> 'Долевая территориальная нагрузка ОПЯ' ... applying
#            ✔ done in 0.71s
#          CHANGE: hFxSLive: 'hFxSLive' -> 'Долевая территориальная нагрузка ОПЯ по обжитой территории' ... applying
#            ✔ done in 0.85s
#          CHANGE: hNormTot: 'hNormTot' -> 'Градация опасности нормативная, вся территория' ... applying
#            ✔ done in 0.81s
#          CHANGE: hExpertTot: 'hExpertTot' -> 'Градация опасности экспертная, вся территория' ... applying
#            ✔ done in 0.82s
#          CHANGE: hNormLive: 'hNormLive' -> 'Градация опасности нормативная, освоенная территория' ... applying
#            ✔ done in 0.88s
#          CHANGE: hExpertLive: 'hExpertLive' -> 'Градация опасности экспертная, освоенная территория' ... applying
#            ✔ done in 0.83s
#          CHANGE: rNiNA_ho: 'rNiNA_ho' -> 'Число населенных пунктов в зоне ОПЯ' ... applying
#            ✔ done in 0.85s
#          CHANGE: rNF_ho: 'rNF_ho' -> 'Доля населенных пунктов в зоне ОПЯ' ... applying
#            ✔ done in 0.84s
#          CHANGE: rSiHA_ho: 'rSiHA_ho' -> 'Количество м2 жилья в зоне ОПЯ' ... applying
#            ✔ done in 0.92s
#          CHANGE: rSF_ho: 'rSF_ho' -> 'Доля м2 жилья в зоне ОПЯ' ... applying
#            ✔ done in 0.97s
#          CHANGE: rViHA_ho: 'rViHA_ho' -> 'Стоимость в опасной зоне указанного ОПЯ_Жильё' ... applying
#            ✔ done in 0.85s
#          CHANGE: rVaR_ho: 'rVaR_ho' -> 'Стоимость под риском указанного ОПЯ_Жильё' ... applying
#            ✔ done in 0.85s
#          CHANGE: rLiHA_ro: 'rLiHA_ro' -> 'Протяженность дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.85s
#          CHANGE: rLF_ro: 'rLF_ro' -> 'Доля дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.85s
#          CHANGE: rViHA_ro: 'rViHA_ro' -> 'Стоимость в опасной зоне указанного ОПЯ_Автодороги' ... applying
#            ✔ done in 0.83s
#          CHANGE: rVaR_ro: 'rVaR_ro' -> 'Стоимость под риском указанного ОПЯ_Автодороги' ... applying
#            ✔ done in 0.82s
#          CHANGE: rLiHA_ra: 'rLiHA_ra' -> 'Протяженность дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.84s
#          CHANGE: rLF_ra: 'rLF_ra' -> 'Доля дорог в зоне ОПЯ' ... applying
#            ✔ done in 0.91s
#          CHANGE: rViHA_ra: 'rViHA_ra' -> 'Стоимость в опасной зоне указанного ОПЯ_ЖД' ... applying
#            ✔ done in 0.87s
#          CHANGE: rVaR_ra: 'rVaR_ra' -> 'Стоимость под риском указанного ОПЯ_ЖД' ... applying
#            ✔ done in 0.76s
#          CHANGE: rSiHA_ag: 'rSiHA_ag' -> 'Площадь в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.84s
#          ...processed 50/67 fields
#          CHANGE: rSF_ag: 'rSF_ag' -> 'Доля площади в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.81s
#          CHANGE: rViHA_ag: 'rViHA_ag' -> 'Стоимость в опасной зоне указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.91s
#          CHANGE: rVaR_ag: 'rVaR_ag' -> 'Стоимость под риском указанного ОПЯ_сельхоз' ... applying
#            ✔ done in 0.75s
#          CHANGE: rSiHA_fo: 'rSiHA_fo' -> 'Площадь в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.91s
#          CHANGE: rSF_fo: 'rSF_fo' -> 'Доля площади в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.87s
#          CHANGE: rViHA_fo: 'rViHA_fo' -> 'Стоимость в опасной зоне указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.89s
#          CHANGE: rVaR_fo: 'rVaR_fo' -> 'Стоимость под риском указанного ОПЯ_лесхоз' ... applying
#            ✔ done in 0.75s
#          CHANGE: rSiHA_in: 'rSiHA_in' -> 'Площадь в опасной зоне указанного ОПЯ_пром' ... applying
#            ✔ done in 0.81s
#          CHANGE: rSF_in: 'rSF_in' -> 'Доля площади в опасной зоне указанного ОПЯ_пром' ... applying
#            ✔ done in 0.83s
#          CHANGE: rViHA_in: 'rViHA_in' -> 'Стоимость в опасной зоне указанного ОПЯ_промышленность' ... applying
#            ✔ done in 0.95s
#          CHANGE: rVaR_in: 'rVaR_in' -> 'Стоимость под риском указанного ОПЯ_промышленность' ... applying
#            ✔ done in 0.84s
#          CHANGE: rViHA_sum: 'rViHA_sum' -> 'Стоимость в опасной зоне указанного ОПЯ_все реципиенты' ... applying
#            ✔ done in 0.82s
#          CHANGE: rVaR_sum: 'rVaR_sum' -> 'Стоимость под риском указанного ОПЯ_все реципиенты' ... applying
#            ✔ done in 0.92s
#          CHANGE: rNiHA_pop: 'rNiHA_pop' -> 'Число жителей в опасной зоне' ... applying
#            ✔ done in 0.82s
#          CHANGE: rNF_pop: 'rNF_pop' -> 'Доля в опасной зоне от общего числа жителей' ... applying
#            ✔ done in 0.92s
#          CHANGE: rNaR_pop: 'rNaR_pop' -> 'Жители "под годовым риском"' ... applying
#            ✔ done in 0.75s
#        FC summary: processed=67, changed=63, skipped=4 | took 54.12s
#
# [4/6] Summary across all FCs in 'risk'
#        Total fields seen: 670
#        Total fields changed: 630
#        Total skipped: 41
#        Skip reasons:
#          alias not found in Excel: 40
#          template fc skipped: 1
#
# [5/6] Example changes (first 10):
#        [KHMAO_hazHeat_MO] region: 'region' -> 'Регион' in 6.24s
#        [KHMAO_hazHeat_MO] MO: 'MO' -> 'МО' in 0.81s
#        [KHMAO_hazHeat_MO] area: 'area' -> 'Площадь общая' in 0.84s
#        [KHMAO_hazHeat_MO] areaLive: 'areaLive' -> 'Площадь освоенная' in 0.77s
#        [KHMAO_hazHeat_MO] areaLiveF: 'areaLiveF' -> 'Площадь освоенная, доля' in 0.80s
#        [KHMAO_hazHeat_MO] sTot: 'sTot' -> 'Подверженная область в МО' in 0.80s
#        [KHMAO_hazHeat_MO] sTotFrac: 'sTotFrac' -> 'Подверженная область в МО, доля' in 0.95s
#        [KHMAO_hazHeat_MO] sLive: 'sLive' -> 'Подверженная область на освоенной территории' in 0.81s
#        [KHMAO_hazHeat_MO] sLiveFrac: 'sLiveFrac' -> 'Подверженная область на освоенной территории, доля' in 0.87s
#        [KHMAO_hazHeat_MO] sDensity: 'sDensity' -> 'Плотность очагов' in 0.86s
#
# [6/6] DONE. DRY_RUN=False.

# %%
ECON_FDS     = "economics"   # feature dataset that holds Economics layers
SHEET_INDEX  = 0             # 0 = Economics (as you said)
DRY_RUN      = False         # True → only print; False → apply AlterField
VERBOSE_SKIPS = False        # True → print per-field skips
LOG_EVERY    = 25            # heartbeat every N fields

# ========= UTILS =========
def print_flush(*args, **kwargs):
    print(*args, **kwargs); sys.stdout.flush()

def secs(dt): return f"{dt:.2f}s"

def pick_col(cands, cols):
    for c in cands:
        if c in cols:
            return c
    raise ValueError(f"Не найден столбец среди вариантов: {cands} | имеющиеся: {list(cols)}")

# ========= READ ALIAS MAP FROM EXCEL (SHEET 0 = ECONOMICS) =========
t0 = time.time()
print_flush(f"[1/6] Reading Excel: {EXCEL_PATH} (sheet index={SHEET_INDEX}) ...")
df = pd.read_excel(EXCEL_PATH, sheet_name=SHEET_INDEX)
print_flush(f"       Rows read: {len(df)}; Columns: {list(df.columns)}")

# Normalize headers for flexible detection
hdr_map = {c: str(c).strip().lower() for c in df.columns}
df.columns = [hdr_map[c] for c in df.columns]

# Candidate columns for field names and aliases
name_candidates  = [ "field_name_tot", "название поля", "name"]
alias_candidates = ["псевдонимы", "псевдоним", "alias", "field_alias"]

name_col  = pick_col(name_candidates,  df.columns)
alias_col = pick_col(alias_candidates, df.columns)
print_flush(f"       Detected columns -> name: '{name_col}', alias: '{alias_col}'")

# Build mapping: exact field name (as in GDB) -> alias
df = df[[name_col, alias_col]].dropna()
df[name_col]  = df[name_col].astype(str).str.strip()
df[alias_col] = df[alias_col].astype(str).str.strip()

alias_map_exact = dict(zip(df[name_col], df[alias_col]))
alias_map_lower = {k.lower(): v for k, v in alias_map_exact.items()}

print_flush(f"       Alias rows usable: {len(alias_map_exact)} "
            f"(example: {list(alias_map_exact.items())[:3]})")
print_flush(f"       Excel read & mapping built in {secs(time.time()-t0)}")

# ========= FIND FEATURE CLASSES IN 'economics' =========
arcpy.env.workspace = os.path.join(gdb_path, ECON_FDS)
fcs = arcpy.ListFeatureClasses() or []
print_flush(f"\n[2/6] Scanning feature dataset: {ECON_FDS}")
print_flush(f"       Feature classes found: {len(fcs)}")
if fcs:
    preview = ", ".join(fcs[:5])
    print_flush(f"       First few FCs: {preview}{' ...' if len(fcs) > 5 else ''}")

# ========= APPLY ALIASES =========
print_flush(f"\n[3/6] Starting alias updates (DRY_RUN={DRY_RUN}) ...")

changes = []   # (fc, field_name, old_alias, new_alias, duration_s)
skipped = []   # (fc, field_name, reason)

grand_total_fields = 0
grand_to_change    = 0

for idx, fc in enumerate(fcs, start=1):
    # optional: skip templates if any
    if "template" in fc.lower():
        skipped.append((fc, None, "template fc skipped"))
        continue

    fc_path = os.path.join(gdb_path, ECON_FDS, fc)
    print_flush(f"\n[FC {idx}/{len(fcs)}] {fc} -> {fc_path}")
    t_fc = time.time()

    try:
        fields = arcpy.ListFields(fc_path)
    except Exception as e:
        print_flush(f"       ERROR: cannot ListFields -> {e}")
        skipped.append((fc, None, f"ListFields error: {e}"))
        continue

    # exclude OID/Geometry
    data_fields = [f for f in fields if f.type not in ("OID", "Geometry")]
    print_flush(f"       Fields (excl. OID/Geometry): {len(data_fields)}")
    grand_total_fields += len(data_fields)

    to_change = 0
    processed = 0

    for i, f in enumerate(data_fields, start=1):
        processed += 1
        # heartbeat
        if (processed % LOG_EVERY) == 0:
            print_flush(f"         ...processed {processed}/{len(data_fields)} fields")

        desired = alias_map_exact.get(f.name) or alias_map_lower.get(f.name.lower())
        if not desired:
            if VERBOSE_SKIPS:
                print_flush(f"         SKIP (no alias in Excel): {f.name} | current='{f.aliasName}'")
            skipped.append((fc, f.name, "alias not found in Excel"))
            continue

        current_alias = f.aliasName or ""
        if current_alias == desired:
            if VERBOSE_SKIPS:
                print_flush(f"         OK (already correct): {f.name} -> '{current_alias}'")
            skipped.append((fc, f.name, "already correct"))
            continue

        to_change += 1
        t_field = time.time()
        msg = f"         CHANGE: {f.name}: '{current_alias}' -> '{desired}'"
        if DRY_RUN:
            print_flush(msg + " [dry-run]")
            changes.append((fc, f.name, current_alias, desired, 0.0))
            continue

        print_flush(msg + " ... applying")
        try:
            arcpy.management.AlterField(
                in_table=fc_path,
                field=f.name,
                new_field_name=None,        # keep actual name
                new_field_alias=desired,    # set alias
                field_type=None,
                field_length=None,
                field_is_nullable=None,
                clear_field_alias=False
            )
            dur = time.time() - t_field
            print_flush(f"           ✔ done in {secs(dur)}")
            changes.append((fc, f.name, current_alias, desired, dur))
        except Exception as e:
            print_flush(f"           ✖ ERROR: {e}")
            skipped.append((fc, f.name, f"ERROR: {e}"))

    dur_fc = time.time() - t_fc
    grand_to_change += to_change
    print_flush(f"       FC summary: processed={processed}, changed={to_change}, "
                f"skipped={processed - to_change} | took {secs(dur_fc)}")

# ========= REPORT =========
print_flush(f"\n[4/6] Summary across all FCs in '{ECON_FDS}'")
print_flush(f"       Total fields seen: {grand_total_fields}")
print_flush(f"       Total fields changed: {grand_to_change}")
print_flush(f"       Total skipped: {len(skipped)}")

# breakdown of skip reasons (top few)
reason_counts = {}
for _, _, r in skipped:
    reason_counts[r] = reason_counts.get(r, 0)
# Out:
# [1/6] Reading Excel: C:\Users\User\Documents\ЦГД\Структура базы_v03.xlsx (sheet index=0) ...
#        Rows read: 48; Columns: ['Группа полей', 'field_name', 'field_name_tot', 'Тип данных', 'alias', 'Размерность', 'Описание', 'Откуда берутся данные', 'Если есть modelBuilder']
#        Detected columns -> name: 'field_name_tot', alias: 'alias'
#        Alias rows usable: 47 (example: [('region', 'Регион'), ('MO', 'МО'), ('area', 'Площадь общая')])
#        Excel read & mapping built in 0.09s
#
# [2/6] Scanning feature dataset: economics
#        Feature classes found: 5
#        First few FCs: KHMAO_houses_src, KHMAO_forest_src, KHMAO_agriculture_src, KHMAO_roads_src, KHMAO_economics_MO
#
# [3/6] Starting alias updates (DRY_RUN=False) ...
#
# [FC 1/5] KHMAO_houses_src -> C:\Users\User\Documents\ЦГД\KHMAO_RiskProfile_30-09-2025\KHMAO_RiskProfile\Default.gdb\economics\KHMAO_houses_src
#        Fields (excl. OID/Geometry): 11
#          CHANGE: region: 'region' -> 'Регион' ... applying
#            ✔ done in 0.60s
#        FC summary: processed=11, changed=1, skipped=10 | took 0.80s
#
# [FC 2/5] KHMAO_forest_src -> C:\Users\User\Documents\ЦГД\KHMAO_RiskProfile_30-09-2025\KHMAO_RiskProfile\Default.gdb\economics\KHMAO_forest_src
#        Fields (excl. OID/Geometry): 12
#        FC summary: processed=12, changed=0, skipped=12 | took 0.20s
#
# [FC 3/5] KHMAO_agriculture_src -> C:\Users\User\Documents\ЦГД\KHMAO_RiskProfile_30-09-2025\KHMAO_RiskProfile\Default.gdb\economics\KHMAO_agriculture_src
#        Fields (excl. OID/Geometry): 8
#        FC summary: processed=8, changed=0, skipped=8 | took 0.17s
#
# [FC 4/5] KHMAO_roads_src -> C:\Users\User\Documents\ЦГД\KHMAO_RiskProfile_30-09-2025\KHMAO_RiskProfile\Default.gdb\economics\KHMAO_roads_src
#        Fields (excl. OID/Geometry): 52
#          CHANGE: region: 'region' -> 'Регион' ... applying
#            ✔ done in 0.70s
#          ...processed 25/52 fields
#          ...processed 50/52 fields
#        FC summary: processed=52, changed=1, skipped=51 | took 0.88s
#
# [FC 5/5] KHMAO_economics_MO -> C:\Users\User\Documents\ЦГД\KHMAO_RiskProfile_30-09-2025\KHMAO_RiskProfile\Default.gdb\economics\KHMAO_economics_MO
#        Fields (excl. OID/Geometry): 49
#          CHANGE: region: 'region' -> 'Регион' ... applying
#            ✔ done in 0.77s
#          CHANGE: MO: 'MO' -> 'МО' ... applying
#            ✔ done in 0.84s
#          CHANGE: area: 'area' -> 'Площадь общая' ... applying
#            ✔ done in 0.69s
#          CHANGE: areaLive: 'areaLive' -> 'Площадь освоенная' ... applying
#            ✔ done in 0.79s
#          CHANGE: areaLiveF: 'areaLiveF' -> 'Площадь освоенная, доля' ... applying
#            ✔ done in 0.82s
#          CHANGE: hoPrice1m: 'hoPrice1m' -> 'Жилье_Нормативная стоимость 1м' ... applying
#            ✔ done in 0.87s
#          CHANGE: hoSurface: 'hoSurface' -> 'Жилье_Общая площадь' ... applying
#            ✔ done in 0.80s
#          CHANGE: hoPriceTot: 'hoPriceTot' -> 'Жилье_Суммарная стоимость' ... applying
#            ✔ done in 0.87s
#          CHANGE: hoAreaHab: 'hoAreaHab' -> 'Жилье_Площадь под жильем' ... applying
#            ✔ done in 0.86s
#          CHANGE: hoDensity: 'hoDensity' -> 'Жилье_Плотность жилья' ... applying
#            ✔ done in 0.83s
#          CHANGE: hoPriceDen: 'hoPriceDen' -> 'Жилье_Плотность стоимости' ... applying
#            ✔ done in 0.83s
#          CHANGE: hoNum: 'hoNum' -> 'Жилье_Количество домов' ... applying
#            ✔ done in 0.77s
#          CHANGE: settelNum: 'settelNum' -> 'Число населенных пунктов' ... applying
#            ✔ done in 0.85s
#          CHANGE: roLenTot: 'roLenTot' -> 'Дороги_Длина' ... applying
#            ✔ done in 0.86s
#          CHANGE: roLenLoc: 'roLenLoc' -> 'Дороги_ДлинаМестные' ... applying
#            ✔ done in 0.78s
#          CHANGE: roLenReg: 'roLenReg' -> 'Дороги_ДлинаРегиональные' ... applying
#            ✔ done in 0.74s
#          CHANGE: roLenFed: 'roLenFed' -> 'Дороги_ДлинаФедеральные' ... applying
#            ✔ done in 0.78s
#          CHANGE: roPr1kmLoc: 'roPr1kmLoc' -> 'Дороги_1кмМестные' ... applying
#            ✔ done in 0.78s
#          CHANGE: roPr1kmReg: 'roPr1kmReg' -> 'Дороги_1кмРегиональные' ... applying
#            ✔ done in 0.81s
#          CHANGE: roPr1kmFed: 'roPr1kmFed' -> 'Дороги_1кмФедеральные' ... applying
#            ✔ done in 0.74s
#          CHANGE: roPriceTot: 'roPriceTot' -> 'Дороги_Суммарная стоимость' ... applying
#            ✔ done in 0.76s
#          CHANGE: roDencity: 'roDencity' -> 'Дороги_Плотность' ... applying
#            ✔ done in 0.78s
#          ...processed 25/49 fields
#          CHANGE: roPriceDen: 'roPriceDen' -> 'Дороги_Плотность стоимости' ... applying
#            ✔ done in 0.75s
#          CHANGE: agAreaTot: 'agAreaTot' -> 'Сельхоз_Площадь' ... applying
#            ✔ done in 0.76s
#          CHANGE: agPrice1km: 'agPrice1km' -> 'Сельхоз_УдельнаяСтоимость' ... applying
#            ✔ done in 0.70s
#          CHANGE: agPriceTotal: 'agPriceTotal' -> 'Сельхоз_ПолнаяСтоимость' ... applying
#            ✔ done in 0.77s
#          CHANGE: agDensity: 'agDensity' -> 'Сельхоз_Плотность' ... applying
#            ✔ done in 0.80s
#          CHANGE: foAreaTot: 'foAreaTot' -> 'Лесхоз_Площадь' ... applying
#            ✔ done in 0.82s
#          CHANGE: foPrice1km: 'foPrice1km' -> 'Лесхоз_УдельнаяСтоимость' ... applying
#            ✔ done in 0.73s
#          CHANGE: foPriceTotal: 'foPriceTotal' -> 'Лесхоз_ПолнаяСтоимость' ... applying
#            ✔ done in 0.83s
#          CHANGE: foDensity: 'foDensity' -> 'Лесхоз_Плотность' ... applying
#            ✔ done in 0.76s
#          CHANGE: inAreaTot: 'inAreaTot' -> 'Производство_Площадь' ... applying
#            ✔ done in 0.87s
#          CHANGE: inPrice1km: 'inPrice1km' -> 'Производство_УдельнаяСтоимость' ... applying
#            ✔ done in 0.83s
#          CHANGE: inPriceTotal: 'inPriceTotal' -> 'Производство_Совокупная Стоимость' ... applying
#            ✔ done in 0.74s
#          CHANGE: inDensity: 'inDensity' -> 'Производство_Плотность' ... applying
#            ✔ done in 0.74s
#          CHANGE: raLenTot: 'raLenTot' -> 'ЖД_Длина' ... applying
#            ✔ done in 0.79s
#          CHANGE: raPr1kmEle: 'raPr1kmEle' -> 'ЖД_1км' ... applying
#            ✔ done in 0.81s
#          CHANGE: raPr1kmNE: 'raPr1kmNE' -> 'ЖД_1км' ... applying
#            ✔ done in 0.79s
#          CHANGE: raPriceTot: 'raPriceTot' -> 'ЖД_Суммарная стоимость' ... applying
#            ✔ done in 0.88s
#          CHANGE: raDencity: 'raDencity' -> 'ЖД_Плотность' ... applying
#            ✔ done in 0.92s
#          CHANGE: raPriceDen: 'raPriceDen' -> 'ЖД_Плотность стоимости' ... applying
#            ✔ done in 0.80s
#          CHANGE: foVolume: 'foVolume' -> 'Лесхоз_ЗапасДревесины' ... applying
#            ✔ done in 0.81s
#          CHANGE: foPrice1m3: 'foPrice1m3' -> 'Лесхоз_Стоимость1м3' ... applying
#            ✔ done in 0.81s
#          CHANGE: popTotal: 'popTotal' -> 'Население_всего' ... applying
#            ✔ done in 0.79s
#          CHANGE: popDMax: 'popDMax' -> 'Население_ПлотностьМаксимум' ... applying
#            ✔ done in 0.83s
#          CHANGE: popDMed: 'popDMed' -> 'Население_ПлотностьМедиана_весьМО' ... applying
#            ✔ done in 0.72s
#          CHANGE: popDMedL: 'popDMedL' -> 'Население_ПлотностьМедиана_ОсвоеннаяТерритория' ... applying
#            ✔ done in 0.77s
#        FC summary: processed=49, changed=47, skipped=2 | took 37.70s
#
# [4/6] Summary across all FCs in 'economics'
#        Total fields seen: 132
#        Total fields changed: 49
#        Total skipped: 83
